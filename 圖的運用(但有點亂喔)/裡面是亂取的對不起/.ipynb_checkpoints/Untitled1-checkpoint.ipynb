# %%
# %matplotlib inline
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["font.sans-serif"]='Microsoft JhengHei'
import plotly.offline
import plotly.express as px
import plotly.graph_objects as go
import plotly.subplots
import squarify
import pandas as pd
weather=pd.read_csv('weather_sample.csv',header=0,parse_dates=['年月'])
weather
# Out:
#            年月  東京-平均氣溫(℃)  東京-降雨量合計(mm)  東京-日照時間(時間)  大阪-平均氣溫(℃)  \
# 0  2015-01-01         5.8          92.5        182.0         6.1
# 1  2015-02-01         5.7          62.0        166.9         6.9
# 2  2015-03-01        10.3          94.0        194.2        10.2
# 3  2015-04-01        14.5         129.0        149.5        15.9
# 4  2015-05-01        21.1          88.0        240.6        21.5
# 5  2015-06-01        22.1         195.5        137.3        22.9
# 6  2015-07-01        26.2         234.5        181.8        27.0
# 7  2015-08-01        26.7         103.5        137.6        28.6
# 8  2015-09-01        22.6         503.5        113.3        23.2
# 9  2015-10-01        18.4          57.0        181.3        19.0
# 10 2015-11-01        13.9         139.5        120.1        15.2
# 11 2015-12-01         9.3          82.5        162.0        10.1
# 12 2016-01-01         6.1          85.0        201.5         6.8
# ...

# %%
plt.ylim([0,30])
sns.lineplot(data=weather,x='年月',y='東京-平均氣溫(℃)')
# Out:
# <AxesSubplot:xlabel='年月', ylabel='東京-平均氣溫(℃)'>

# %%
plt.ylim([0,30])
sns.lineplot(data=weather,x='年月',y='東京-平均氣溫(℃)')
plt.xticks(rotation=90)
# Out:
# (array([16436., 16617., 16801., 16983., 17167., 17348., 17532., 17713.,
#         17897.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
weather_index=pd.read_csv('weather_sample.csv',header=0,parse_dates=['年月'],index_col=0)
tmp_ave=weather_index[['東京-平均氣溫(℃)','大阪-平均氣溫(℃)','那霸-平均氣溫(℃)','東京-平均氣溫(℃)']]
tmp_ave
# Out:
#             東京-平均氣溫(℃)  大阪-平均氣溫(℃)  那霸-平均氣溫(℃)  東京-平均氣溫(℃)
# 年月
# 2015-01-01         5.8         6.1        16.6         5.8
# 2015-02-01         5.7         6.9        16.8         5.7
# 2015-03-01        10.3        10.2        19.0        10.3
# 2015-04-01        14.5        15.9        22.2        14.5
# 2015-05-01        21.1        21.5        24.9        21.1
# 2015-06-01        22.1        22.9        28.7        22.1
# 2015-07-01        26.2        27.0        29.0        26.2
# 2015-08-01        26.7        28.6        28.7        26.7
# 2015-09-01        22.6        23.2        27.8        22.6
# 2015-10-01        18.4        19.0        25.5        18.4
# 2015-11-01        13.9        15.2        23.8        13.9
# 2015-12-01         9.3        10.1        20.1         9.3
# 2016-01-01         6.1         6.8        17.4         6.1
# 2016-02-01         7.2         7.4        16.9         7.2
# 2016-03-01        10.1        10.8        18.7        10.1
# ...

# %%
ax=sns.lineplot(data=tmp_ave)
plt.xticks(rotation=90)
ax.legend(loc='lower left',bbox_to_anchor=(1,0))

# %%
cafe=pd.read_csv('cafe.csv',header=0,index_col=0)
cafe
# Out:
#          1月   2月   3月   4月   5月   6月   7月   8月   9月  10月  11月  12月
# 商品
# 熱咖啡     980  828  823  650  732  653  763  650  791  732  758  996
# 冰咖啡     314  269  419  596  669  672  840  944  903  555  865  318
# 熱茶      670  678  500  418  469  471  320  380  420  390  606  558
# 冰茶      280  320  430  450  550  580  628  734  494  304  473  280
# 餅乾      311  332  200  403  350  369  219  328  316  379  434  366
# 冰淇淋     150  128  200  284  319  320  650  559  500  265  412  152
# 普通甜甜圈   205  278  249  424  372  371  426  269  200  297  427  311
# 巧克力甜甜圈  242  296  387  358  335  407  447  449  163  229  354  301
# 三明治     124  174  147  184  160  187  149  195  145  156  126  200

# %%
sns.heatmap(cafe)
# Out:
# <AxesSubplot:ylabel='商品'>

# %%
sns.heatmap(cafe,linewidths=1,annot=True,fmt='d')
# Out:
# <AxesSubplot:ylabel='商品'>

# %%
sns.heatmap(cafe,linewidths=1,cmap='coolwarm',annot=True,fmt='d')
# Out:
# <AxesSubplot:ylabel='商品'>
