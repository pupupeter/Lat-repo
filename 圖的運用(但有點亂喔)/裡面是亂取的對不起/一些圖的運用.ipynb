# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('python2011nsc.csv')
df
# Out:
#       NO  Gender  DateOfBirth  Race  FaEdu  MomEdu  FaexpEdu  CoexpEdu  \
# 0      1       1           84     1      4       2         2         2
# 1      2       1           84     1      3       2         2         2
# 2      3       1           84     1      1       2         2         2
# 3      4       1           83     1      2       2         2         2
# 4      5       1           84     3      4       4         2         2
# ..   ...     ...          ...   ...    ...     ...       ...       ...
# 525  526       1           83     1      3       3         2         2
# 526  527       1           84     1      3       3         2         2
# 527  528       1           84     1      2       2         2         2
# 528  529       1           84     1      4       3         2         2
# 529  530       1           84     3      3       3         2         2
#
#      Income  Grade  ...  c8  c9  c10        pl    al        ss        tr  \
# 0         3   75.0  ...   1   1    1  3.666667  2.50  5.000000  2.000000
# 1         3   55.0  ...   3   3    1  4.333333  3.25  3.333333  2.000000
# 2         2   65.0  ...   2   2    2  4.000000  3.50  4.000000  2.000000
# 3         7   60.0  ...   1   1    1  3.333333  2.50  3.000000  3.000000
# 4         5   50.0  ...   2   3    2  3.666667  4.25  3.333333  3.333333
# ..      ...    ...  ...  ..  ..  ...       ...   ...       ...       ...
# 525       3   78.0  ...   3   3    3  3.333333  3.00  3.000000  3.000000
# 526       3   86.0  ...   2   2    3  4.333333  4.00  3.333333  2.333333
# 527       1   66.0  ...   2   3    3  3.666667  4.25  2.333333  3.000000
# 528       7   84.0  ...   1   1    1  4.333333  3.50  3.333333  2.000000
# 529       5   79.0  ...   1   2    2  5.000000  3.25  5.000000  1.000000
#
#      blue  achievement  alienance
# 0    2.25     4.000000   1.000000
# 1    3.25     2.666667   2.333333
# 2    2.50     3.000000   2.000000
# 3    1.75     2.000000   1.000000
# 4    3.50     2.000000   2.333333
# ..    ...          ...        ...
# 525  3.00     3.000000   3.000000
# 526  3.00     2.333333   2.333333
# 527  2.25     2.333333   2.666667
# 528  2.50     2.000000   1.000000
# 529  2.75     2.666667   1.666667
#
# [530 rows x 43 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('python2011nsc.csv')
plt.plot(df['Grade'])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('python2011nsc.csv')
x=[1,0]
gender=[389,149]
plt.bar(x,gender,color='b')
plt.xticks(x,['male','female'])
plt.show()

# %%
df['Gender'].value_counts().plot.bar(rot=0,colormap='summer')
# Out:
# <AxesSubplot:>

# %%
size=df['Gender'].value_counts()
labels=['male','female']
plt.pie(size,labels=labels,autopct='%.2f%%')
plt.axis('equal')
plt.show()

# %%
plt.hist(df['Grade'],10)
plt.show()

# %%
plt.xlabel('x軸標籤名稱')
plt.ylabel('y軸標籤名稱')
plt.title('圖示名稱')
plt.savefig('儲存圖示名稱')
font = {'family': 'MicroSoft YaHei'}
plt.rc('font',**font)

plt.scatter(df['ss'],df['achievement'],c='darkblue',alpha=.4       )
plt.show()
